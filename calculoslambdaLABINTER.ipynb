# %%
# %pylab inline
# Out:
# Welcome to pylab, a matplotlib-based Python environment [backend: module://IPython.zmq.pylab.backend_inline].
# For more information, type 'help(pylab)'.

# %% [markdown]
# # LED VERDE

# %%
a=loadtxt('datosEspectros/verde.dat')
pixel=a[:,0]
value=a[:,1]
lamb=791.3866346421-(pixel*0.544351006)#Formula resultante de la calibracion con la lampara de hidrogeno
plt.suptitle('En pixeles')
plot(pixel,value)
xlabel('Pixel')
ylabel('#Electrones')
show()
plt.suptitle('En longitudes de onda')
plot(lamb,value)
xlabel('Lambda[nm]')
ylabel('#Electrones')
show()

# %%
expe=loadtxt('datosMonocromador/LED_verde1.dat')
posini=4.7 #en milimetros
paso=expe[:,0]
vale=expe[:,1]
plt.suptitle('Datos experimentales')
plot(paso, vale)
xlabel('Pasos en el tornillo')
ylabel('Voltaje')#Voltaje medido en el osciloscopio
show()

# %% [markdown]
# # LED ROJO

# %%
a=loadtxt('datosEspectros/rojo.dat')
pixel=a[:,0]
value=a[:,1]
lamb=791.3866346421-(pixel*0.544351006)
plt.suptitle('En pixeles')
xlabel('pixel')
ylabel('#electrons')
plot(pixel,value)
show()
plt.suptitle('En longitudes de onda')
xlabel('lambda[nm]')
ylabel('#electrones')
plot(lamb,value)
show()

# %% [markdown]
# Ahora los datos experimentales

# %%
expe=loadtxt('datosMonocromador/LED_rojo.dat')
posini=4.7 #en milimetros
paso=expe[:,0]
vale=expe[:,1]
plt.suptitle('Datos experimentales')
plot(paso, vale)
xlabel('Pasos en el tornillo')
ylabel('Voltaje')#Voltaje medido en el osciloscopio
show()

# %% [markdown]
# # LED BLANCO

# %%
a=loadtxt('datosEspectros/blanco.dat')
pixel=a[:,0]
value=a[:,1]
lamb=791.3866346421-(pixel*0.544351006)
plt.suptitle('En pixeles')
xlabel('pixel')
ylabel('#electrons')
plot(pixel,value)
show()
plt.suptitle('En longitudes de onda')
xlabel('lambda[nm]')
ylabel('#electrones')
plot(lamb,value)
show()

# %% [markdown]
# Ahora los datos experimentales con el monocromador

# %%
expe=loadtxt('datosMonocromador/LED_blanco_160.dat')
posini=4.7 #en milimetros
paso=expe[:,0]
vale=expe[:,1]
plt.suptitle('Datos experimentales')
plot(paso, vale)
xlabel('Pasos en el tornillo')
ylabel('Voltaje')#Voltaje medido en el osciloscopio
show()

# %% [markdown]
# # LED INFRARROJO 810nm

# %%
a=loadtxt('datosEspectros/infrarrojoqo.dat')
pixel=a[:,0]
value=a[:,1]
lamb=791.3866346421-(pixel*0.544351006)
plt.suptitle('En pixeles')
xlabel('pixel')
ylabel('#electrons')
plot(pixel,value)
show()
plt.suptitle('En longitudes de onda')
xlabel('lambda[nm]')
ylabel('#electrones')
plot(lamb,value)
show()

# %% [markdown]
# Datos experimentales tomados con el monocromador

# %%
expe=loadtxt('datosMonocromador/LED_810.dat')
posini=4.7 #en milimetros
paso=expe[:,0]
vale=expe[:,1]
plt.suptitle('Datos experimentales')
plot(paso, vale)
xlabel('Pasos en el tornillo')
ylabel('Voltaje')#Voltaje medido en el osciloscopio
show()

# %% [markdown]
# # LED AMARILLO

# %%
a=loadtxt('datosEspectros/amarillo.dat')
pixel=a[:,0]
value=a[:,1]
lamb=791.3866346421-(pixel*0.544351006)
plt.suptitle('En pixeles')
xlabel('pixel')
ylabel('#electrons')
plot(pixel,value)
show()
plt.suptitle('En longitudes de onda')
xlabel('lambda[nm]')
ylabel('#electrones')
plot(lamb,value)
show()

# %%
expe=loadtxt('datosMonocromador/LED_amarillo.dat')
posini=4.7 #en milimetros
paso=expe[:,0]
vale=expe[:,1]
plt.suptitle('Datos experimentales')
plot(paso, vale)
xlabel('Pasos en el tornillo')
ylabel('Voltaje')#Voltaje medido en el osciloscopio
show()

# %% [markdown]
# # LED AZUL

# %%
a=loadtxt('datosEspectros/azul.dat')
pixel=a[:,0]
value=a[:,1]
lamb=791.3866346421-(pixel*0.544351006)
plt.suptitle('En pixeles')
xlabel('pixel')
ylabel('#electrons')
plot(pixel,value)
show()
plt.suptitle('En longitudes de onda')
xlabel('lambda[nm]')
ylabel('#electrones')
plot(lamb,value)
show()

# %%
expe=loadtxt('datosMonocromador/LED_azul.dat')
posini=4.7 #en milimetros
paso=expe[:,0]
vale=expe[:,1]
plt.suptitle('Datos experimentales')
plot(paso, vale)
xlabel('Pasos en el tornillo')
ylabel('Voltaje')#Voltaje medido en el osciloscopio
show()

# %% [markdown]
# # LED VIOLETA QO

# %%
a=loadtxt('datosEspectros/violetaqo.dat')
pixel=a[:,0]
value=a[:,1]
lamb=791.3866346421-(pixel*0.544351006)
plt.suptitle('En pixeles')
xlabel('pixel')
ylabel('#electrons')
plot(pixel,value)
show()
plt.suptitle('En longitudes de onda')
xlabel('lambda[nm]')
ylabel('#electrones')
plot(lamb,value)
show()

# %%
expe=loadtxt('datosMonocromador/LED_violeta_QO.dat')
posini=4.7 #en milimetros
paso=expe[:,0]
vale=expe[:,1]
plt.suptitle('Datos experimentales')
plot(paso, vale)
xlabel('Pasos en el tornillo')
ylabel('Voltaje')#Voltaje medido en el osciloscopio
show()

# %% [markdown]
# #     LED INFRARROJO CERCANO

# %%
a=loadtxt('datosEspectros/infracercaqo.dat')
pixel=a[:,0]
value=a[:,1]
lamb=791.3866346421-(pixel*0.544351006)
plt.suptitle('En pixeles')
xlabel('pixel')
ylabel('#electrons')
plot(pixel,value)
show()
plt.suptitle('En longitudes de onda')
xlabel('lambda[nm]')
ylabel('#electrones')
plot(lamb,value)
show()

# %%
expe=loadtxt('datosMonocromador/LED_infrarrojo_C.dat')
posini=4.7 #en milimetros
paso=expe[:,0]
vale=expe[:,1]
plt.suptitle('Datos experimentales')
plot(paso, vale)
xlabel('Pasos en el tornillo')
ylabel('Voltaje')#Voltaje medido en el osciloscopio
show()

# %% [markdown]
# # LED INFRARROJO

# %%
a=loadtxt('datosEspectros/infrarrojo.dat')
pixel=a[:,0]
value=a[:,1]
lamb=791.3866346421-(pixel*0.544351006)
plt.suptitle('En pixeles')
xlabel('pixel')
ylabel('#electrons')
plot(pixel,value)
show()
plt.suptitle('En longitudes de onda')
xlabel('lambda[nm]')
ylabel('#electrones')
plot(lamb,value)
show()

# %% [markdown]
# Dado que la longitud de onda que emite este LED es en infrarrojo, tanto que la camara CCD no alcanza a detectar, no se observaron se;al en el Monocromador.
